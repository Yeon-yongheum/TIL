# %% [markdown]
# ## 우리가 만들고자 하는 딕셔너리의 최종 모습
#
# * Key값을 movieCd로 하는 이유는 중복 체크를 편하게 하기 위해서! 만약에 키 값이 아니면.. 또다시 반복문 ㅠ
#
# ```
# {
#     '20196309': {
#         'movieCd': '20196309',
#         'movieNm': '스파이더맨',
#         'audiAcc': 6685161
#     },
#     '20183867': {
#         'movieCd': '20183867',
#         'movieNm': '알라딘',
#         'audiAcc': 123213
#     },
#     '20196309': {
#         'movieCd': '20196309',
#         'movieNm': '스파이더맨',
#         'audiAcc': 6685161
#     }
# }
# ```

# %%
# 1. 항상 문제는 쪼개서 풀어야한다! 먼저 하루 데이터 가져와서 만들기!
import requests
key = '----'
targetDt = '20190713' #yyyymmdd
api_url = f'http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchWeeklyBoxOfficeList.json?key={key}&targetDt={targetDt}'
print(api_url)
response = requests.get(api_url).json()

# %%
# 2. 구조 확인하기!
response['boxOfficeResult']['weeklyBoxOfficeList']

# %%
# 3. 내가 원하는 데이터 뽑아내보기!
for i in range(0, 10):
    movieCd = response['boxOfficeResult']['weeklyBoxOfficeList'][i]['movieCd']
    audiAcc = response['boxOfficeResult']['weeklyBoxOfficeList'][i]['audiAcc']
    movieNm = response['boxOfficeResult']['weeklyBoxOfficeList'][i]['movieNm']
    print(movieCd, audiAcc, movieNm)
# 뭔가 반복되는 코드가 있다? -> 나는 더 개선할 여지가 있다!
# 다시 response['boxOfficeResult']['weeklyBoxOfficeList'] 이 것을 보면 리스트!
# 리스트 안에 있는 것 다 내놔!로 표현하면 좋지 않을까.

# %%
# 4. 이제 딕셔너리를 만들어볼까?
# 만들고자하는 결과통을
movie_data = {}
# 리스트에서 꺼내주는 것은 개별 영화에 대한 데이터! 변수명을 movie로 하면 보기가 좀 더 좋다.
for movie in response['boxOfficeResult']['weeklyBoxOfficeList']:
    movie_data[movie.get('movieCd')] = {
                                        '영화코드': movie.get('movieCd'),
                                        '누적관객수': movie.get('audiAcc'),
                                        '영화이름': movie.get('movieNm')
                                    }
print(movie_data)

# %%
# 5일로 늘려보자!
import datetime
import requests
import pprint
key = ''
for i in range(5):
    targetDt = datetime.datetime(2019, 7, 13) - datetime.timedelta(weeks=i)
    targetDt = targetDt.strftime('%Y%m%d') #yyyymmdd
    api_url = f'http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchWeeklyBoxOfficeList.json?key={key}&targetDt={targetDt}&weekGb=0'
    response = requests.get(api_url).json()
    movie_data = {}
    for movie in response['boxOfficeResult']['weeklyBoxOfficeList']:
        movie_data[movie.get('movieCd')] = {
                                            '영화코드': movie.get('movieCd'),
                                            '누적관객수': movie.get('audiAcc'),
                                            '영화이름': movie.get('movieNm')
                                        }
print(movie_data)

pprint.pprint(response)
# Out:
# {'20183867': {'영화코드': '20183867', '누적관객수': '5325767', '영화이름': '알라딘'}, '20183782': {'영화코드': '20183782', '누적관객수': '8344622', '영화이름': '기생충'}, '20196657': {'영화코드': '20196657', '누적관객수': '637747', '영화이름': '맨 인 블랙: 인터내셔널'}, '20182387': {'영화코드': '20182387', '누적관객수': '845012', '영화이름': '엑스맨: 다크 피닉스'}, '20190273': {'영화코드': '20190273', '누적관객수': '77793', '영화이름': '천로역정: 천국을 찾아서'}, '19880001': {'영화코드': '19880001', '누적관객수': '142372', '영화이름': '이웃집 토토로'}, '20191401': {'영화코드': '20191401', '누적관객수': '30244', '영화이름': '업사이드'}, '20198291': {'영화코드': '20198291', '누적관객수': '98703', '영화이름': '로켓맨'}, '20190466': {'영화코드': '20190466', '누적관객수': '17105', '영화이름': '세상을 바꾼 변호인'}, '20184889': {'영화코드': '20184889', '누적관객수': '13887813', '영화이름': '어벤져스: 엔드게임'}}
# {'boxOfficeResult': {'boxofficeType': '주간 박스오피스',
#                      'showRange': '20190610~20190616',
#                      'weeklyBoxOfficeList': [{'audiAcc': '5325767',
#                                               'audiChange': '-18.5',
#                                               'audiCnt': '1426227',
#                                               'audiInten': '-323314',
#                                               'movieCd': '20183867',
#                                               'movieNm': '알라딘',
#                                               'openDt': '2019-05-23',
#                                               'rank': '1',
#                                               'rankInten': '1',
#                                               'rankOldAndNew': 'OLD',
#                                               'rnum': '1',
#                                               'salesAcc': '45417350029',
#                                               'salesAmt': '12481191690',
#                                               'salesChange': '-16.3',
#                                               'salesInten': '-2437499417',
#                                               'salesShare': '38.2',
#                                               'scrnCnt': '1409',
#                                               'showCnt': '31996'},
#                                              {'audiAcc': '8344622',
#                                               'audiChange': '-63.8',
#                                               'audiCnt': '1323415',
#                                               'audiInten': '-2331077',
#                                               'movieCd': '20183782',
#                                               'movieNm': '기생충',
#                                               'openDt': '2019-05-30',
#                                               'rank': '2',
#                                               'rankInten': '-1',
#                                               'rankOldAndNew': 'OLD',
#                                               'rnum': '2',
#                                               'salesAcc': '71569573245',
#                                               'salesAmt': '11235266500',
#                                               'salesChange': '-63.9',
#                                               'salesInten': '-19915122027',
#                                               'salesShare': '34.4',
#                                               'scrnCnt': '1459',
#                                               'showCnt': '41418'},
#                                              {'audiAcc': '637747',
#                                               'audiChange': '100.0',
#                                               'audiCnt': '637747',
#                                               'audiInten': '637747',
#                                               'movieCd': '20196657',
#                                               'movieNm': '맨 인 블랙: 인터내셔널',
#                                               'openDt': '2019-06-12',
#                                               'rank': '3',
#                                               'rankInten': '0',
#                                               'rankOldAndNew': 'NEW',
#                                               'rnum': '3',
#                                               'salesAcc': '5687505010',
#                                               'salesAmt': '5687505010',
#                                               'salesChange': '100.0',
#                                               'salesInten': '5687505010',
#                                               'salesShare': '17.4',
#                                               'scrnCnt': '1150',
#                                               'showCnt': '23939'},
#                                              {'audiAcc': '845012',
#                                               'audiChange': '-85.4',
#                                               'audiCnt': '107944',
#                                               'audiInten': '-629124',
#                                               'movieCd': '20182387',
#                                               'movieNm': '엑스맨: 다크 피닉스',
#                                               'openDt': '2019-06-05',
#                                               'rank': '4',
#                                               'rankInten': '-1',
#                                               'rankOldAndNew': 'OLD',
#                                               'rnum': '4',
#                                               'salesAcc': '7506698060',
#                                               'salesAmt': '902001200',
#                                               'salesChange': '-86.3',
#                                               'salesInten': '-5702695660',
#                                               'salesShare': '2.8',
#                                               'scrnCnt': '704',
#                                               'showCnt': '9859'},
#                                              {'audiAcc': '77793',
#                                               'audiChange': '1645.2',
#                                               'audiCnt': '65305',
#                                               'audiInten': '61563',
#                                               'movieCd': '20190273',
#                                               'movieNm': '천로역정: 천국을 찾아서',
#                                               'openDt': '2019-06-13',
#                                               'rank': '5',
#                                               'rankInten': '13',
#                                               'rankOldAndNew': 'OLD',
#                                               'rnum': '5',
#                                               'salesAcc': '602886030',
#                                               'salesAmt': '515904530',
#                                               'salesChange': '1885.6',
#                                               'salesInten': '489922530',
#                                               'salesShare': '1.6',
#                                               'scrnCnt': '381',
#                                               'showCnt': '2087'},
#                                              {'audiAcc': '142372',
#                                               'audiChange': '-58.6',
#                                               'audiCnt': '41159',
#                                               'audiInten': '-58311',
#                                               'movieCd': '19880001',
#                                               'movieNm': '이웃집 토토로',
#                                               'openDt': '2001-07-28',
#                                               'rank': '6',
#                                               'rankInten': '-2',
#                                               'rankOldAndNew': 'OLD',
#                                               'rnum': '6',
#                                               'salesAcc': '1167697530',
#                                               'salesAmt': '336480720',
#                                               'salesChange': '-58.7',
#                                               'salesInten': '-477289090',
#                                               'salesShare': '1.0',
#                                               'scrnCnt': '342',
#                                               'showCnt': '2734'},
#                                              {'audiAcc': '30244',
#                                               'audiChange': '1242.7',
#                                               'audiCnt': '26962',
#                                               'audiInten': '24954',
#                                               'movieCd': '20191401',
#                                               'movieNm': '업사이드',
#                                               'openDt': '2019-06-13',
#                                               'rank': '7',
#                                               'rankInten': '16',
#                                               'rankOldAndNew': 'OLD',
#                                               'rnum': '7',
#                                               'salesAcc': '262416100',
#                                               'salesAmt': '235760100',
#                                               'salesChange': '1367.6',
#                                               'salesInten': '219696100',
#                                               'salesShare': '0.7',
#                                               'scrnCnt': '188',
#                                               'showCnt': '2185'},
#                                              {'audiAcc': '98703',
#                                               'audiChange': '-63.6',
#                                               'audiCnt': '26252',
#                                               'audiInten': '-45798',
#                                               'movieCd': '20198291',
#                                               'movieNm': '로켓맨',
#                                               'openDt': '2019-06-05',
#                                               'rank': '8',
#                                               'rankInten': '-3',
#                                               'rankOldAndNew': 'OLD',
#                                               'rnum': '8',
#                                               'salesAcc': '851323713',
#                                               'salesAmt': '220061440',
#                                               'salesChange': '-64.9',
#                                               'salesInten': '-407591833',
#                                               'salesShare': '0.7',
#                                               'scrnCnt': '472',
#                                               'showCnt': '3155'},
#                                              {'audiAcc': '17105',
#                                               'audiChange': '2457.5',
#                                               'audiCnt': '15396',
#                                               'audiInten': '14794',
#                                               'movieCd': '20190466',
#                                               'movieNm': '세상을 바꾼 변호인',
#                                               'openDt': '2019-06-13',
#                                               'rank': '9',
#                                               'rankInten': '34',
#                                               'rankOldAndNew': 'OLD',
#                                               'rnum': '9',
#                                               'salesAcc': '139578330',
#                                               'salesAmt': '125506330',
#                                               'salesChange': '2216.5',
#                                               'salesInten': '120088330',
#                                               'salesShare': '0.4',
#                                               'scrnCnt': '185',
#                                               'showCnt': '1263'},
#                                              {'audiAcc': '13887813',
#                                               'audiChange': '-60.3',
#                                               'audiCnt': '12483',
#                                               'audiInten': '-18938',
#                                               'movieCd': '20184889',
#                                               'movieNm': '어벤져스: 엔드게임',
#                                               'openDt': '2019-04-24',
#                                               'rank': '10',
#                                               'rankInten': '-1',
#                                               'rankOldAndNew': 'OLD',
#                                               'rnum': '10',
#                                               'salesAcc': '121721428090',
#                                               'salesAmt': '107767720',
#                                               'salesChange': '-59.4',
#                                               'salesInten': '-157967920',
#                                               'salesShare': '0.3',
#                                               'scrnCnt': '69',
#                                               'showCnt': '578'}],
#                      'yearWeekTime': '201924'}}

# %%
# movie_data 초기화가 되어버린다! 밖으로 꺼내자.
import datetime
import requests

key = '----'
movie_data = {}
for i in range(5):
    targetDt = datetime.datetime(2019, 7, 13) - datetime.timedelta(weeks=i)
    targetDt = targetDt.strftime('%Y%m%d') #yyyymmdd
    api_url = f'http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchWeeklyBoxOfficeList.json?key={key}&targetDt={targetDt}&weekGb=0'
    response = requests.get(api_url).json()
    for movie in response['boxOfficeResult']['weeklyBoxOfficeList']:
        movie_data[movie.get('movieCd')] = {
                                            '영화코드': movie.get('movieCd'),
                                            '누적관객수': movie.get('audiAcc'),
                                            '영화이름': movie.get('movieNm')
                                        }
print(movie_data)

# %%
# 값이 최신 데이터가 아니라 옛날 데이터이다. 
# 이를 해결하기 위해서는 옛날부터해서 2019년 7월 13일로 오거나
# 조건문을 추가한다!
# movie_data 초기화가 되어버린다! 밖으로 꺼내자.
import datetime
import requests

key = '----'
movie_data = {}
for i in range(5):
    targetDt = datetime.datetime(2019, 7, 13) - datetime.timedelta(weeks=i)
    targetDt = targetDt.strftime('%Y%m%d') #yyyymmdd
    api_url = f'http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchWeeklyBoxOfficeList.json?key={key}&targetDt={targetDt}&weekGb=0'
    response = requests.get(api_url).json()
    for movie in response['boxOfficeResult']['weeklyBoxOfficeList']:
        # 무슨 값을 어디에 있는 값이랑 비교를 해야 하는지 반드시 생각해보자.
        # -> 가져온 데이터에 있는 값이 지금 누적해서 결과를 만드는 movie_data에 있는지를 확인!
        if movie.get('movieCd') not in movie_data:
            movie_data[movie.get('movieCd')] = {
                                                '영화코드': movie.get('movieCd'),
                                                '누적관객수': movie.get('audiAcc'),
                                                '영화이름': movie.get('movieNm')
                                            }
print(movie_data)

# %%
# 끝났다. 이제 csv에 저장하자
import csv
with open('boxoffice.csv', 'w', encoding='utf-8') as f:
    fieldnames = ['영화코드', '누적관객수', '영화이름'] # 여기만 변경
    csv_writer = csv.DictWriter(f, fieldnames=fieldnames)
    csv_writer.writeheader()
    for item in movie_data.values(): # 딕셔너리 만든 것 반복
        csv_writer.writerow(item)

# %%
# 최종 주석 없는 코드
import csv
import datetime
import requests

key = '----'
movie_data = {}
for i in range(5):
    targetDt = datetime.datetime(2019, 7, 13) - datetime.timedelta(weeks=i)
    targetDt = targetDt.strftime('%Y%m%d')
    api_url = f'http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchWeeklyBoxOfficeList.json?key={key}&targetDt={targetDt}&weekGb=0'
    response = requests.get(api_url).json()
    for movie in response['boxOfficeResult']['weeklyBoxOfficeList']:
        if movie.get('movieCd') not in movie_data:
            movie_data[movie.get('movieCd')] = {
                                                '영화코드': movie.get('movieCd'),
                                                '누적관객수': movie.get('audiAcc'),
                                                '영화이름': movie.get('movieNm')
                                            }

with open('boxoffice.csv', 'w', encoding='utf-8') as f:
    fieldnames = ['영화코드', '누적관객수', '영화이름'] 
    csv_writer = csv.DictWriter(f, fieldnames=fieldnames)
    csv_writer.writeheader()
    for item in movie_data.values():
        csv_writer.writerow(item)
